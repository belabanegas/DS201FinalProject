# %% [markdown]
# <a href="https://colab.research.google.com/github/belabanegas/DS201FinalProject/blob/main/Copy_of_project_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/Covid Data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/Covid Data.csv")
df.drop (columns= ['PNEUMONIA', 'COPD','HIPERTENSION','TOBACCO','INMSUPR'])
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  AGE  \
# 0            2             1    1             1  03/05/2020       97   65
# 1            2             1    2             1  03/06/2020       97   72
# 2            2             1    2             2  09/06/2020        1   55
# 3            2             1    1             1  12/06/2020       97   53
# 4            2             1    2             1  21/06/2020       97   68
# ...        ...           ...  ...           ...         ...      ...  ...
# 1048570      2            13    2             1  9999-99-99       97   40
# 1048571      1            13    2             2  9999-99-99        2   51
# 1048572      2            13    2             1  9999-99-99       97   55
# 1048573      2            13    2             1  9999-99-99       97   28
# 1048574      2            13    2             1  9999-99-99       97   52
#
#          PREGNANT  DIABETES  ASTHMA  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  \
# ...
